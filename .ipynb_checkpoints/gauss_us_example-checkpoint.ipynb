# %% [markdown]
# # Example: using US sampler to sample a 2D Gaussian pdf

# %%
import numpy as np

# define a desired covariance matrix for 2D Gaussian
cov = [[1.0, 0.95], [0.95, 1.0]]
icov = np.linalg.inv(cov)

# %%
import usample.usample
import numpy as np
import emcee

def log_prob_fn(p, means, icov):
        
    lpf = - 0.5 * np.dot(p , np.dot( icov , p ) )
    
    return lpf

icov = [[ 10.25641026,  -9.74358974], [ -9.74358974,  10.25641026]]
gaussian_center = [0., 0.]

us = usample.UmbrellaSampler( log_prob_fn , lpfargs=[gaussian_center,icov],   debug=True,  burn_acor=20 )

#
# Now add some umbrellas.
# First, define some temperatures to run with. 
# Use eight umbrellas, with temperature vals going from 1 to 10
#

temps = np.linspace( 1 , 10 , 8 ) 

#
# Then add an umbrella at each temperature. Use four walkers, and give some initial conditions
# Can be added individually, or in bulk:
#

us.add_umbrellas( temps , numwalkers=4 , ic=gaussian_center , sampler=emcee.EnsembleSampler )

# 
# Then run for 10000 steps in each window.
# Output stats every [freq] steps
# Try to replica exchange [repex]-many walkers every [freq] steps
#
# stop when GR indicator drops to 0.01

pos_us, weights, prob = us.run(10000 , freq=1000, repex=10, grstop = 0.01   )
# Out:
#     [d]: Total windows: 8
#     [d]: Temperatures: [ 1.          2.28571429  3.57142857  4.85714286  6.14285714  7.42857143
#   8.71428571 10.        ]
#  :- Completed 1000 of 10000 iterations.
#     [d]: max gr: 0.03931403048624782
#     [d]: Repex summary (84.28 %):  [ 7.  8.  7. 10.  8. 10.  9.  0.]
#  :- Completed 2000 of 10000 iterations.
#     [d]: max gr: 0.022521471422638273
#     [d]: Repex summary (78.57 %):  [ 2.  9. 10.  9.  9.  9.  7.  0.]
#  :- Completed 3000 of 10000 iterations.
#     [d]: max gr: 0.01436982987796287
#     [d]: Repex summary (84.28 %):  [ 7.  9.  7.  9.  9.  8. 10.  0.]
#  :- Completed 4000 of 10000 iterations.
#     [d]: max gr: 0.011686437461778443
#     [d]: Repex summary (82.85 %):  [ 5.  8. 10.  9.  7.  9. 10.  0.]
#  :- Completed 5000 of 10000 iterations.
#     [d]: max gr: 0.011357598004177571
#     [d]: Repex summary (78.57 %):  [ 2.  7. 10.  7. 10. 10.  9.  0.]
#  :- Completed 6000 of 10000 iterations.
#     [d]: max gr: 0.01159335168403941
#     [d]: Repex summary (82.85 %):  [ 7.  5.  8. 10.  9. 10.  9.  0.]
#  :- Completed 7000 of 10000 iterations.
#     [d]: max gr: 0.01001957646946594
#     [d]: Repex summary (74.28 %):  [3. 7. 8. 9. 9. 7. 9. 0.]
#  :- Completed 8000 of 10000 iterations.
#     [d]: max gr: 0.007988992974363063
#     [d]: Repex summary (82.85 %):  [ 5.  8. 10.  8.  7. 10. 10.  0.]
#     [d]: z values [0.02320098 0.05278921 0.08200599 0.11098506 0.1398089  0.16851387
#  0.1971091  0.22558688]
#     [d]: Acor values [42.5, 36.18, 49.05, 45.14, 46.19, 46.76, 50.43, 53.23]
#     [d]: Percentage burned: 11.5390625 % (29540 of 256000 )

# %%
print("shape of weights array: %s and walker position array: %s"%(str(np.shape(weights)), 
                                                                  str(np.shape(pos_us[:,0]))))
# Out:
# shape of weights array: (192000, 1) and walker position array: (192000,)

# %%
# %matplotlib inline 

from plot_utils import plot_pretty, plot_2d_dist

plot_pretty()
x1d = pos_us[:,0]; x2d = pos_us[:,1]; 
weights = weights.ravel()

clevs = (0.683, 0.955, 0.997, 0.9999, 0.99999, 0.9999999999) # contour levels to plot


plot_2d_dist(x1d, x2d, xlim=[-7,7], ylim =[-7,7], nxbins=100, nybins=100, 
             clevs=clevs, weights=weights, smooth=None, 
             xlabel='x', ylabel='y')
# Out:
# /Users/crjm/repos/usample/plot_utils.py:68: UserWarning: Log scale: values of z <= 0 have been masked
#   ax.contour(H, linewidths=np.linspace(1,2,len(lvls)), colors='black', levels = sorted(lvls),
